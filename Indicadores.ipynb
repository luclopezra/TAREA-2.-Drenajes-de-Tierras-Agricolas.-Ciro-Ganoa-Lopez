# %% [markdown]
# <a href="https://colab.research.google.com/github/luclopezra/TAREA-2.-Drenajes-de-Tierras-Agricolas.-Ciro-Ganoa-Lopez/blob/main/Indicadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INDICADORES DE COMPACTACIÓN PREPSUEL ELITE FLOWER**

# %% [markdown]
# **_Bloque 67_**

# %%
# libraries
import seaborn as sns
import pandas as pd
import numpy as np

# Create a dataset
data = {
  "1": [0, 0,0 ,6,6,9],
  "2": [6,7,6,0,0,0],
  "3": [0, 0,0 ,9,6,9],
  "4": [6,7,5,0,0,0],
  "5": [0, 0,0 ,8,6,6],
  "6": [8,9,9,0,0,0],
  "7": [0, 0,0 ,6,6,6],
  "8": [9,9,6,0,0,0],
  "9": [0, 0,0 ,6,6,6],
  "10": [9,6,6,0,0,0],
  "11": [0, 0,0 ,7,6,9],
  "12": [9,9,6,0,0,0],
  "13": [0, 0,0 ,9,9,8],
  "14": [9,7,8,0,0,0],
  "15": [0, 0,0 ,6,6,5],
  "16": [9,9,8,0,0,0],
  "17": [0, 0,0 ,7,9,9],
}
df = pd.DataFrame(data)


# plot a heatmap with annotation
sns.heatmap(df,  cmap="RdPu",annot=True, annot_kws={"size": 7})
# Out:
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = {
  "1": [0, 0,0 ,300,200,150],
  "2": [200, 200, 250,0,0,0],
  "3": [0, 0, 0,190,200,110],
  "4": [200, 250, 300,0,0,0],
  "5": [0, 0, 0,200,200,200],
  "6": [200, 90, 150,0,0,0],
  "7": [0, 0, 0,250,200,200],
  "8": [200, 150, 200,0,0,0],
  "9": [0, 0, 0,300,300,250],
  "10": [150, 250, 200,0,0,0],
  "11": [0, 0, 0,250,250,200],
  "12": [150, 250, 300,0,0,0],
  "13": [0, 0, 0,250,190,300],
  "14": [150, 250, 200,0,0,0],
  "15": [0, 0, 0,300,200,250],
  "16": [150, 190, 250,0,0,0],
  "17": [0, 0, 0,250,200,150],
}

#load data into a DataFrame object:
df = pd.DataFrame(data)
sns.heatmap(df, cmap="YlOrBr")
# Out:
# <Axes: >

# %%
# libraries
import seaborn as sns
import pandas as pd
import numpy as np

# Create a dataset
data = {
  "1": [0, 0,0 ,9,9,9],
  "2": [9,9,9,0,0,0],
  "3": [0, 0,0 ,9,9,9],
  "4": [9,9,9,0,0,0],
  "5": [0, 0,0 ,9,9,9],
  "6": [9,9,9,0,0,0],
  "7": [0, 0,0 ,9,9,9],
  "8": [9,9,9,0,0,0],
  "9": [0, 0,0 ,9,9,9],
  "10": [9,9,9,0,0,0],
  "11": [0, 0,0 ,9,9,9],
  "12": [9,9,9,0,0,0],
  "13": [0, 0,0 ,9,9,9],
  "14": [9,9,9,0,0,0],
  "15": [0, 0,0 ,9,9,9],
  "16": [9,9,9,0,0,0],
  "17": [0, 0,0 ,9,9,9],
}
df = pd.DataFrame(data)


# plot a heatmap with annotation
sns.heatmap(df,  cmap="RdPu",annot=True, annot_kws={"size": 7})
# Out:
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = {
  "1": [0, 0,0 ,40,200,200],
  "2": [200, 150, 140,0,0,0],
  "3": [0, 0, 0,190,180,110],
  "4": [200, 200, 100,0,0,0],
  "5": [0, 0, 0,150,150,100],
  "6": [100, 110, 100,0,0,0],
  "7": [0, 0, 0,140,160,200],
  "8": [140, 100, 150,0,0,0],
  "9": [0, 0, 0,200,170,200],
  "10": [150, 160, 40,0,0,0],
  "11": [0, 0, 0,180,200,110],
  "12": [120, 140, 90,0,0,0],
  "13": [0, 0, 0,150,110,200],
  "14": [160, 110, 110,0,0,0],
  "15": [0, 0, 0,140,200,150],
  "16": [100, 100, 90,0,0,0],
  "17": [0, 0, 0,110,200,130],
}

#load data into a DataFrame object:
df = pd.DataFrame(data)
sns.heatmap(df, cmap="YlOrBr")
# Out:
# <Axes: >
